# %%
import pandas as pd

# %%
HS_data = pd.read_csv('dataset/Health_Sciences_Data_File.csv')
HS_data
# Out:
#       Idnum    Date Sex  Age    Ht     Wt  RF 2  RF 3  RF 4  RF 5  ...  \
# 0     M0001  2002-2   M   19  65.0  195.4     5     1     1     0  ...
# 1     M0002  2002-2   M   19  68.5  201.4     5     2     2     0  ...
# 2     M0003  2002-2   M   21  69.8  133.8     5     2     6     0  ...
# 3     M0004  2002-2   M   18  66.0  148.0     5     1     6     0  ...
# 4     M0005  2002-2   M   23  67.0  148.7     5     2     6     2  ...
# ...     ...     ...  ..  ...   ...    ...   ...   ...   ...   ...  ...
# 6271  F3612  2013-4   F   18  68.0  193.8     1     3     1     0  ...
# 6272  F3613  2013-4   F   19  64.0  106.0     1     2     1     0  ...
# 6273  F3614  2013-4   F   23  67.0  155.8     1     3     1     0  ...
# 6274  F3615  2013-4   F   18  68.0  152.6     1     3     1     0  ...
# 6275  F3616  2013-4   F   18  65.0  131.6     1     3     1     0  ...
#
#       Unnamed: 161  Unnamed: 162  Unnamed: 163  Unnamed: 164  Unnamed: 165  \
# ...

# %%
data_dict = pd.read_csv('dataset/Data_Dictionary.csv')
data_dict
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1      Column
# 2         NaN
# 3         NaN
# 4           A
# 5           B
# 6           C
# 7           D
# 8           E
# 9           F
# 10          G
# 11          H
# 12        NaN
# 13          I
# 14          J
# 15          K
# 16        NaN
# 17          L
# 18        NaN
# 19          M
# 20          N
# 21          O
# 22          P
# 23          Q
# 24          R
# 25          S
# 26          T
# 27          U
# 28          V
# 29          W
# 30          X
# 31          Y
# 32          Z
# 33         AA
# 34         AB
# 35         AC
# 36         AD
# 37         AE
# 38         AF
# 39         AG
# 40         AH
# 41         AI
# 42         AJ
# 43         AK
# 44         AL
# 45         AM
# 46         DI
# 47        NaN
#
#                                                          Codes Used with HESC 101 Fitness Testing Data Set  \
# 0                                                 NaN
# ...
